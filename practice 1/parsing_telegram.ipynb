# %%
import requests
import telethon
from telethon import TelegramClient
import asyncio
import json

# %%
api_id = 'api id от приложения тг'
api_hash = 'api hash от приложения тг'
phone = 'Телефон'

# %%
client = TelegramClient(phone, api_id, api_hash)

# %% [markdown]
# Парсинг группы

# %%
async def quick_chat_check(chat_id):
    async with TelegramClient('session_name', api_id, api_hash) as client:
        try:
            chat = await client.get_entity(int(chat_id))
            
            print("=== ИНФОРМАЦИЯ О ЧАТЕ ===")
            print(f"💬 Название: {getattr(chat, 'title', 'Без названия')}")
            print(f"🆔 ID: {chat.id}")
            print(f"👤 Username: @{getattr(chat, 'username', 'Нет')}")
            print(f"📊 Тип чата: {type(chat).__name__}")
            print(f"👥 Участников: {getattr(chat, 'participants_count', 'Неизвестно')}")
            
            # Быстрая проверка последних сообщений
            print(f"\n=== ПОСЛЕДНИЕ 10 СООБЩЕНИЙ ===")
            messages = await client.get_messages(chat, limit=100)
            
            for i, msg in enumerate(messages, 1):
                sender = await msg.get_sender()
                sender_name = getattr(sender, 'first_name', getattr(sender, 'title', 'Неизвестно'))
                message_preview = msg.text[:60] + '...' if msg.text and len(msg.text) > 60 else (msg.text or '[медиа]')
                print(f"{i:2d}. {sender_name}: {message_preview}")
            
        except Exception as e:
            print(f"❌ Ошибка: {e}")

# %%
await quick_chat_check('-4512620959')
# Out:
# === ИНФОРМАЦИЯ О ЧАТЕ ===
# 💬 Название: Чисто КэСэДва и ф0рест
# 🆔 ID: 4512620959
# 👤 Username: @Нет
# 📊 Тип чата: Chat
# 👥 Участников: 7
#
# === ПОСЛЕДНИЕ 10 СООБЩЕНИЙ ===
#  1. Ruslan: хахахахаха
#  2. Брюхич🕸: 😌 **ПРОСТРЕЛ. В СМОК. БЕЗ ЗУМА. В ГОЛОВУ. ОТОМСТИЛ.**
#  3. Брюхич🕸: Бля че сегодня происходит
#  4. Ruslan: Это я когда карты пикаем
#  5. Брюхич🕸: 🇮🇹😁** tN1R решил применить **[**секретную стратегию**](https...
#  6. Брюхич🕸: 🤣
#  7. Вовчик🕸️: а че  спириты 1:9 летят
#  8. Ruslan: Нихуя всадил
#  9. Брюхич🕸: 🙂 Как это зарегало? Тот самый VAC от игрока Inner Circle.
# 10. Ruslan: Дефолтный тиммейт Руслана в катке на повышение:
# 11. Ruslan: мне кажется так и есть
# 12. Ruslan: хорош
# 13. Брюхич🕸: ёбаные 5лвла
# 14. Брюхич🕸: 1 в 1 выходили
# 15. Брюхич🕸: Че в голове бля должно быть
# 16. yungyuga 🕸️: просто типы лс ебанные
# 17. Брюхич🕸: Ч за х бля
# 18. Брюхич🕸: Хотя инста работает
# 19. Брюхич🕸: [медиа]
# 20. Брюхич🕸: Они че со смоками  сделали
# 21. Брюхич🕸: И такая хуйня не только на мираже
# 22. Брюхич🕸: Бля 3-4к ело типы смок окно на мираже не попадают
# 23. Брюхич🕸: Я демку скинул, че ты хотел
# 24. Ruslan: Сколько нахуй
# 25. Брюхич🕸: Я ебал
# 26. Брюхич🕸: Мб у вас получится
# 27. Брюхич🕸: [медиа]
# 28. Брюхич🕸: Из-за какой-то хуиты
# 29. Брюхич🕸: Ебать очко горит бля
# 30. Брюхич🕸: Ебать я там раздал бля клатч 1vs5
# 31. Брюхич🕸: У меня кс не видит ее
# 32. Брюхич🕸: И нихуя
# 33. Брюхич🕸: Да ебать я демку скачиваю с фасика
# Вставляю все куда нужно
# 34. Брюхич🕸: Нет
# 35. Ruslan: А в кс не сохраняется?
# 36. Ruslan: Xz
# 37. Брюхич🕸: У меня нихуя не получается
# 38. Брюхич🕸: Как демку с фасета чекнуть
# 39. Брюхич🕸: БЛять
# 40. Брюхич🕸: Последний раз зм смотрел в 2015
# 41. Брюхич🕸: Я бля вообще хз как он должен выдаваться
# 42. Ruslan: Ебать Ямаль 2 в рейтинге золотого мяча, сказать что я в ахуе...
# 43. Вовчик🕸️: я пока не могу
# 44. yungyuga 🕸️: давид вова залетай е
# 45. yungyuga 🕸️: нам двоих надо
# 46. yungyuga 🕸️: пацаны
# 47. Дава 🕸️: если народ соберётся мб зайду
# 48. Вовчик🕸️: в часов 21, я еще кс удалил
# 49. yungyuga 🕸️: лс
# 50. yungyuga 🕸️: билять
# 51. Брюхич🕸: У меня интернета нет
# 52. yungyuga 🕸️: а во скок будешь
# 53. Вовчик🕸️: не смогу наверно
# 54. Вовчик🕸️: я не дома еще
# 55. yungyuga 🕸️: @SellPr1ncess пойдешь??
# 56. yungyuga 🕸️: пошлите в 7
# 57. yungyuga 🕸️: че мб в контру седня??
# 58. yungyuga 🕸️: ………..
# 59. yungyuga 🕸️: **🥳**** FISHMAN — С ДНЁМ РОЖДЕНИЯ!**
#
# Сегодня небезызвестный...
# 60. Брюхич🕸: 🇷🇺 I_OLGA стала официальным стримером Virtus.Prо.
#
# ✅ Лучший ...
# 61. Брюхич🕸: Нихуя
# 62. Ruslan: хахахахах
# 63. Брюхич🕸: Почему мне ебучая гремучая хуйня выпала
# 64. Брюхич🕸: ДА БЛЯЯЯЯЯ
# 65. Ruslan: Касик на базу
# 66. Ruslan: [медиа]
# 67. Брюхич🕸: Так щас не работает
# 68. yungyuga 🕸️: а че есть акк свободный??
# 69. Брюхич🕸: Это Аяврик катал
# 70. yungyuga 🕸️: типо лютый??
# 71. Брюхич🕸: Надо фэсит играть
# 72. Ruslan: как в это играть
# 73. Ruslan: это ваще пиздец
# 74. Брюхич🕸: Во во
# 75. Ruslan: Такие сука идиоты игра.т, я в ахуе
# 76. Ruslan: Пиздец, играл в соревы, тип простоял пол игры на респе, я пы...
# 77. Брюхич🕸: [медиа]
# 78. Ruslan: Ебешь
# 79. Брюхич🕸: [медиа]
# 80. Брюхич🕸: [медиа]
# 81. Дава 🕸️: хахахахаха
# 82. Брюхич🕸: [медиа]
# 83. Брюхич🕸: Пшли
# 84. Дава 🕸️: у меня не работает никакие
# 85. Дава 🕸️: пошлите в стиме
# 86. Брюхич🕸: Ща
# 87. Ruslan: попробуй general (ALT2), через него у меня зашло
# 88. Брюхич🕸: Ты мне скидывал
# 89. Брюхич🕸: А
# 90. Ruslan: ПРОГАЙ КАКОЙ ПОЛЬЗУЕШЬСЯ?
# 91. Брюхич🕸: До этого то работал
# 92. Брюхич🕸: Да он апдейт вечно чекает два дня уже
# 93. Ruslan: ты чем пользуешься?
# 94. Брюхич🕸: Ну ч идем?
# 95. Брюхич🕸: Бля у меня дискорд вечно грузится
# 96. Дава 🕸️: я фасик не играю больше
# 97. Дава 🕸️: прем или мм можно
# 98. Дава 🕸️: над еженедельку пофармить
# 99. Дава 🕸️: нет
# 100. Брюхич🕸: ФАСИК?

# %%
await quick_chat_check('@exploitex')
# Out:
# ❌ Ошибка: invalid literal for int() with base 10: '@exploitex'

# %% [markdown]
# Парсинг канала, где больше 200 подписчиков

# %%
async def parse_channel(channel_username_or_id):
    async with TelegramClient('session_name', api_id, api_hash) as client:
        await client.start(phone=phone)  # или phone=phone_number
        
        print(f"🔍 Парсинг канала: {channel_username_or_id}")
        
        try:
            # Получаем канал
            channel = await client.get_entity(channel_username_or_id)
            
            print("✅ КАНАЛ НАЙДЕН:")
            print(f"   📢 Название: {getattr(channel, 'title', 'Без названия')}")
            print(f"   🔢 ID: {channel.id}")
            print(f"   👤 Username: @{getattr(channel, 'username', 'Нет username')}")
            print(f"   📝 Описание: {getattr(channel, 'about', 'Нет описания')}")
            print(f"   👥 Подписчиков: {getattr(channel, 'participants_count', 'Неизвестно')}")
            
            # Получаем сообщения
            print(f"\n📨 Получаем сообщения...")
            messages_data = []
            
            async for message in client.iter_messages(channel, limit=100):
                message_info = {
                    'id': message.id,
                    'date': message.date.isoformat(),
                    'text': message.text or '',
                    'views': getattr(message, 'views', 0),
                    'forwards': getattr(message, 'forwards', 0),
                    'media': bool(message.media),
                    'media_type': str(message.media.__class__.__name__) if message.media else None
                }
                messages_data.append(message_info)
                
                # Выводим в консоль
                views = getattr(message, 'views', 0)
                print(f"   [{message.date.strftime('%d.%m %H:%M')}] 👁️ {views} | {message.text[:80]}{'...' if len(message.text or '') > 80 else ''}")
            
            # Сохраняем в JSON
            channel_data = {
                'channel_info': {
                    'name': getattr(channel, 'title', 'Без названия'),
                    'id': channel.id,
                    'username': getattr(channel, 'username', ''),
                    'description': getattr(channel, 'about', ''),
                    'subscribers': getattr(channel, 'participants_count', 0)
                },
                'messages': messages_data
            }
            
            filename = f"channel_{getattr(channel, 'username', channel.id)}.json"
            with open(filename, 'w', encoding='utf-8') as f:
                json.dump(channel_data, f, ensure_ascii=False, indent=2)
            
            print(f"\n🎉 ПАРСИНГ ЗАВЕРШЕН!")
            print(f"   💾 Сохранено сообщений: {len(messages_data)}")
            print(f"   📁 Файл: {filename}")
            
            return channel_data
            
        except Exception as e:
            print(f"❌ Ошибка: {e}")
            return None

  # или по ID: -100123456789

# %%
# Запуск для канала по username
await parse_channel('exploitex')
# Out:
# 🔍 Парсинг канала: exploitex
# ✅ КАНАЛ НАЙДЕН:
#    📢 Название: Эксплойт
#    🔢 ID: 1307778786
#    👤 Username: @exploitex
#    📝 Описание: Нет описания
#    👥 Подписчиков: None
#
# 📨 Получаем сообщения...
#    [15.10 14:02] 👁️ 40492 | ⚡️ Доллар упал до 76 рублей.
#
# Очень вовремя.
#
# @exploitex
#    [15.10 13:37] 👁️ 65676 | **Новый iPad Pro на M5 **— это буквально MacBook в планшете.
#
# Толщина всего 5,1 ...
#    [15.10 13:13] 👁️ 82056 | ⚡️ **MacBook Pro на M5 в 3,5 раза (!)** [быстрее](https://www.apple.com/macbook-...
#    [15.10 13:08] 👁️ 91496 |
#    [15.10 13:08] 👁️ 94703 | **⚡️ MacBook Pro M5 и iPad Pro анонсированы —** Apple [открыла](https://www.appl...
#    [15.10 12:30] 👁️ 91790 |
#    [15.10 12:30] 👁️ 91539 |
#    [15.10 12:30] 👁️ 92105 |
#    [15.10 12:30] 👁️ 88843 |
#    [15.10 12:30] 👁️ 90975 |
#    [15.10 12:30] 👁️ 88736 |
#    [15.10 12:30] 👁️ 88549 | **Плюшевые Пепе нашли новый дом —** подписчики присылают фото наших игрушек по м...
#    [15.10 10:57] 👁️ 133700 |
#    [15.10 10:57] 👁️ 135553 |
#    [15.10 10:57] 👁️ 133496 |
#    [15.10 10:57] 👁️ 134904 | **iPhone 17 Pro Max начали... киснуть **— это не шутка: юзеры [сообщают](https:/...
#    [15.10 10:31] 👁️ 133505 | **Пиратский Steam прокачали до неузнаваемости **— Hydra получила САМУЮ крупную о...
#    [15.10 09:39] 👁️ 144439 | **IT-сектор России на грани КАТАСТРОФЫ **— многие компании [закроются](https://w...
#    [15.10 08:27] 👁️ 168519 | **⚡️ Макан НЕ ЯВИЛСЯ в военкомат** — в Москве сегодня ожидалось [прибытие](https...
#    [15.10 08:05] 👁️ 163006 | **В YouTube появилось ЖИДКОЕ СТЕКЛО **— Google [полностью](https://support.googl...
#    [15.10 07:35] 👁️ 154105 |
#    [15.10 07:35] 👁️ 156930 |
#    [15.10 07:35] 👁️ 155721 |
#    [15.10 07:35] 👁️ 147541 | Возле Москва-Сити MR [строит](https://jois.moscow/?utm_source=telegram&utm_mediu...
#    [15.10 05:55] 👁️ 171198 |
#    [15.10 05:55] 👁️ 176873 |
#    [15.10 05:55] 👁️ 173635 |
#    [15.10 05:55] 👁️ 172555 |
#    [15.10 05:55] 👁️ 167536 |
#    [15.10 05:55] 👁️ 170335 |
#    [15.10 05:55] 👁️ 165879 | **Новенькие китайские Geely теряют управление прямо во время ДВИЖЕНИЯ **— машины...
#    [14.10 21:28] 👁️ 204172 | **Динозавров ВОСКРЕСИЛИ в Китае, ну почти **— Unitree использует своих робособак...
#    [14.10 17:30] 👁️ 209555 | ⚡️ **В ChatGPT добавят ЭРОТИКУ** —  бот сможет заниматься секстингом с пользоват...
#    [14.10 16:45] 👁️ 203097 | Доллар: падает на пару рублей.
#
# Вся телега:
#
# @exploitex
#    [14.10 14:35] 👁️ 208681 |
#    [14.10 14:35] 👁️ 210087 |
#    [14.10 14:35] 👁️ 209763 |
#    [14.10 14:35] 👁️ 200381 | У военных США теперь волхак — компания **Anduril** [выпустила](https://www.theve...
#    [14.10 13:13] 👁️ 204186 | Тем временем АвтоВАЗ подготовил авто, за которое не придётся платить утильсбор —...
#    [14.10 12:54] 👁️ 182651 | **⚡️ Решение по утильсбору отложили на МЕСЯЦ **— теперь ожидается, что новые пра...
#    [14.10 11:38] 👁️ 198164 |
#    [14.10 11:38] 👁️ 201689 |
#    [14.10 11:38] 👁️ 193125 |
#    [14.10 11:38] 👁️ 190261 | **Зумеры устроили революцию в Мадагаскаре **— президент страны Андри Радзуэлина ...
#    [14.10 10:50] 👁️ 181978 | В России [появился](https://www.forbes.ru/tekhnologii/547761-andeks-zapustil-v-p...
#    [14.10 10:10] 👁️ 188476 | **Девушка постоянно забывала про таблетки, и парень сделал для неё бота в Telegr...
#    [14.10 09:52] 👁️ 183345 | Зелёная сова достанет вас везде.
#
# @exploitex
#    [14.10 09:20] 👁️ 185444 | У российских ритейлеров [стартовал предзаказ](https://www.ferra.ru/news/notebook...
#    [14.10 08:55] 👁️ 203670 | ⚡️ **Новый утильсбор ПЕРЕНОСИТСЯ **— первый вице-премьер РФ Денис Мантуров [попр...
#    [14.10 07:59] 👁️ 204107 | ⚡️ **Лента выкупает всю сеть О'кей **— сумму сделки [оценивают](https://www.inte...
#    [14.10 05:42] 👁️ 217854 | ⚡️ **Скамеры начали массово подделывать голоса ДЕТЕЙ **с помощью ИИ, чтобы [выма...
#    [13.10 21:00] 👁️ 230829 | **Windows 10 КОНЕЦ** — сегодня Microsoft официально прекращают поддержку системы...
#    [13.10 16:40] 👁️ 221868 | **7-Zip УНИЧТОЖИТ ваш комп вирусам**и — в сервисе [нашли](https://www.tomshardwa...
#    [13.10 16:02] 👁️ 213279 | В Твиттере [раскрыли](https://x.com/immasiddx/status/1977384634250875262) единст...
#    [13.10 15:22] 👁️ 196474 | Избегаем трудностей с оформлением документов и расчётов **из-за новой ставки НДС...
#    [13.10 15:13] 👁️ 186795 | ⚡️** Аниме** по **Duolingo** **ВЫШЛО **— первый эпизод мульта уже можно глянуть ...
#    [13.10 14:35] 👁️ 195764 | **Чтобы завести кошку или собаку в России, теперь нужен будет ДОПУСК **— Минприр...
#    [13.10 14:03] 👁️ 187128 | В России появится **Институт социальной архитектуры** — об этом [заявил](https:/...
#    [13.10 13:41] 👁️ 191859 | Бизнес-идея: пермяк [отсудил](https://perm.rbc.ru/perm/freenews/68e7fca89a794705...
#    [13.10 10:45] 👁️ 203394 |
#    [13.10 10:45] 👁️ 217280 |
#    [13.10 10:45] 👁️ 198341 | **Китайцы выпустили стиралку специально для носков и трусов **— в Dreame Double ...
#    [13.10 09:16] 👁️ 217347 | ⚡️ **Hollywood Undead приедут в Россию** — нас [ждут](http://daily.afisha.ru/new...
#    [13.10 08:46] 👁️ 200216 | Последний шанс залететь на AI Journey Contest с** призовым фондом в 6,5 миллионо...
#    [13.10 07:43] 👁️ 205727 |
#    [13.10 07:43] 👁️ 208947 |
#    [13.10 07:43] 👁️ 200259 |
#    [13.10 07:43] 👁️ 197376 | **Весёлая ферма научит вас кодить** — в [Steam](https://store.steampowered.com/a...
#    [13.10 06:21] 👁️ 223247 | **В Африке диагностируют туберкулез с помощью... КРЫС **— HeroRAT, дрессированны...
#    [12.10 22:57] 👁️ 240009 | Спокойной ночи и приятного аппетита.
#
# Генерации Sora становятся слишком реалисти...
#    [12.10 19:24] 👁️ 236385 | **Все криптокошельки Trust Wallet ОБНУЛИЛИСЬ** — у компании жёсткий сбой.
#
# Не пу...
#    [12.10 16:15] 👁️ 245908 | ⚡️ **Банк России ОТМЕНИЛ голосование **по [выбору](https://t.me/centralbank_russ...
#    [12.10 15:34] 👁️ 237246 |
#    [12.10 15:34] 👁️ 240802 |
#    [12.10 15:34] 👁️ 236617 |
#    [12.10 15:34] 👁️ 227571 | Зовём корешей разбирать «жигуль» — в [Steam](https://store.steampowered.com/app/...
#    [12.10 10:11] 👁️ 244145 | **Зумеры массово ложатся в ДУРКУ, чтобы... отдохнуть **— молодёжь [открыла](http...
#    [12.10 09:01] 👁️ 234986 | **Улететь в Стамбул из Москвы можно за 228 рублей **— цену на ноябрьские рейсы с...
#    [12.10 07:12] 👁️ 223118 | Зависть: в Китае невеста [подарила](http://tomshardware.com/pc-components/gpus/b...
#    [12.10 06:53] 👁️ 207510 |
#    [12.10 06:53] 👁️ 216418 | **Первую в мире мышь... с подогревом и охлаждением выпустили Black Shark **— тем...
#    [11.10 22:12] 👁️ 250676 |
#    [11.10 22:12] 👁️ 250571 | Китай [показал](https://www.nytimes.com/2025/10/10/business/china-solar-tibetan-...
#    [11.10 14:01] 👁️ 233711 | Секрет продуктивности оказался прост.
#
# @exploitex
#    [11.10 10:56] 👁️ 230191 | **Пользователи нашли способ спасти смартфоны Samsung** — он простой и воскресит ...
#    [11.10 09:18] 👁️ 230904 |
#    [11.10 09:18] 👁️ 235325 | ⚡️ **Смартфоны Samsung массово превращаютcя в КИРПИЧ после установки обновы One ...
#    [11.10 07:45] 👁️ 223636 | Единственным стабильным активом оказались... **скины в CS2** — они не только не ...
#    [11.10 06:25] 👁️ 218852 | **Превращаем любое фото или видео в текст** — нашли бесплатную тулзу для Windows...
#    [10.10 22:08] 👁️ 230844 | Трампкоин резко потерял половину цены, но затем кто-то внезапно начал **откупать...
#    [10.10 21:47] 👁️ 221614 | Агент Краснов докладывает.
#
# @exploitex
#    [10.10 21:36] 👁️ 212714 | Полная картина ада на крипторынке:** почти все альткоины в минусе на 50-60%**.
#
# ...
#    [10.10 21:31] 👁️ 206533 | ⚡️ **BTC рухнул до 105 000 долларов** — это самая низкая цена за год.
#
# Тем време...
#    [10.10 21:23] 👁️ 202492 | ⚡️ TON УМЕР — монета резко потеряла в цене 80% стоимости
#
# Что происходит?
#
# @expl...
#    [10.10 21:14] 👁️ 202414 | **⚡️ Вся крипта летит вниз **— торпеду на дно запустил Трамп: он заявил, что США...
#    [10.10 16:51] 👁️ 223856 |
#    [10.10 16:51] 👁️ 238328 |
#    [10.10 16:51] 👁️ 225091 |
#    [10.10 16:51] 👁️ 213830 |
#    [10.10 16:51] 👁️ 209352 | ⚡️ **В Телеграм появилось ЖИДКОЕ СТЕКЛО** — обновление в честь дня рождения Паши...
#
# 🎉 ПАРСИНГ ЗАВЕРШЕН!
#    💾 Сохранено сообщений: 100
#    📁 Файл: channel_exploitex.json
# {'channel_info': {'name': 'Эксплойт',
#   'id': 1307778786,
#   'username': 'exploitex',
#   'description': '',
#   'subscribers': None},
#  'messages': [{'id': 28677,
#    'date': '2025-10-15T14:02:38+00:00',
#    'text': '⚡️ Доллар упал до 76 рублей.\n\nОчень вовремя.\n\n@exploitex',
#    'views': 40492,
#    'forwards': 1531,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28676,
#    'date': '2025-10-15T13:37:39+00:00',
#    'text': '**Новый iPad Pro на M5 **— это буквально MacBook в планшете.\n\nТолщина всего 5,1 мм — тоньше, чем айфон. В основе мощь полноценного процессора M5: LLM и генеративные модели **можно запускать прямо на устройстве.** \n\nТакже внутри до 16 ГБ оперативки, до 2 ТБ SSD, Ultra Retina XDR дисплей до 13 дюймов с 1600 нит. \n\nЦены стартуют от $999 (79 тыс. рублей) за 11 дюймов и $1299 (103 тыс. рублей) за 13 дюймов. Продажи начинаются 22 октября.\n\n@exploitex',
#    'views': 65676,
#    'forwards': 637,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28675,
#    'date': '2025-10-15T13:13:29+00:00',
#    'text': '⚡️ **MacBook Pro на M5 в 3,5 раза (!)** [быстрее](https://www.apple.com/macbook-pro/) прошлых моделей:\n\n— Новый чип M5 с 10-ядерным GPU и нейроускорителями — до 6,7× быстрее в 3D и 4× быстрее в генерации изображений;\n— Рендеринг и монтаж теперь просто летают; \n— Apple Intelligence встроен прямо в систему;\n— Можно суммаризировать тексты, редактировать фото и юзать ChatGPT без облака;\n— Работает сутки на одном заряде;\n— Дисплеи Liquid Retina XDR с яркостью до 1600 нит в HDR, 12-Мп фронтальная камера, шесть динамиков.\n\nЦены стартуют от 1599 долларов (127 тыс. рублей). Доступны два цвета: серебристый и космический чёрный. \n\nПредзаказы уже открыты, продажи начинаются 22 октября.\n\n@exploitex',
#    'views': 82056,
#    'forwards': 1670,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28674,
#    'date': '2025-10-15T13:08:24+00:00',
#    'text': '',
#    'views': 91496,
#    'forwards': 771,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28673,
#    'date': '2025-10-15T13:08:24+00:00',
#    'text': '**⚡️ MacBook Pro M5 и iPad Pro анонсированы —** Apple [открыла](https://www.apple.com/macbook-pro/) предзаказы новинки. \n\nПродажи стартуют 22 октября.\n\nМощь.\n\n@exploitex',
#    'views': 94703,
#    'forwards': 731,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28672,
#    'date': '2025-10-15T12:30:14+00:00',
#    'text': '',
#    'views': 91790,
#    'forwards': 172,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28671,
#    'date': '2025-10-15T12:30:14+00:00',
#    'text': '',
#    'views': 91539,
#    'forwards': 161,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28670,
#    'date': '2025-10-15T12:30:13+00:00',
#    'text': '',
#    'views': 92105,
#    'forwards': 203,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28669,
#    'date': '2025-10-15T12:30:13+00:00',
#    'text': '',
#    'views': 88843,
#    'forwards': 195,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28668,
#    'date': '2025-10-15T12:30:12+00:00',
#    'text': '',
#    'views': 90975,
#    'forwards': 225,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28667,
#    'date': '2025-10-15T12:30:12+00:00',
#    'text': '',
#    'views': 88736,
#    'forwards': 217,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28666,
#    'date': '2025-10-15T12:30:12+00:00',
#    'text': '**Плюшевые Пепе нашли новый дом —** подписчики присылают фото наших игрушек по мотивам самого хайпового подарка Telegram.\n\nЭто ультраредкий дроп: каждая игрушка со своим уникальным скином, сшита вручную и с любовью. Всего 20 штук на весь мир — и каждая уже успела завести свою историю. Пепе Барселона путешествовал по Швейцарии, черный Пепе [прокатился](https://t.me/borz/s/143) в хайповом Porsche 911 вместе с Roxman.\n\nЧто же ждёт их дальше?\n\n@exploitex',
#    'views': 88549,
#    'forwards': 213,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28665,
#    'date': '2025-10-15T10:57:27+00:00',
#    'text': '',
#    'views': 133700,
#    'forwards': 4433,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28664,
#    'date': '2025-10-15T10:57:26+00:00',
#    'text': '',
#    'views': 135553,
#    'forwards': 4422,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28663,
#    'date': '2025-10-15T10:57:26+00:00',
#    'text': '',
#    'views': 133496,
#    'forwards': 4334,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28662,
#    'date': '2025-10-15T10:57:25+00:00',
#    'text': '**iPhone 17 Pro Max начали... киснуть **— это не шутка: юзеры [сообщают](https://www.reddit.com/r/iphone/comments/1o6h9pd/update_on_orange_iphone_17_pro_max_that_turned), что металл на смартфонах окисляется и МЕНЯЕТ ЦВЕТ. \n\nВладелец оранжевой версии рассказал, как его айфон за пару недель превратился в розово-золотой. Пост вызвал бурю сомнений, но новые фото подтвердили, что оттенок действительно изменился.\n\n**Причина в слабом защитном слое анодированного алюминия:** некоторые партии получили неравномерное покрытие, которое со временем окисляется и меняет цвет.\n\nКупил Cosmic Orange, а получил Rose Gold.\n\n@exploitex',
#    'views': 134904,
#    'forwards': 4466,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28661,
#    'date': '2025-10-15T10:31:34+00:00',
#    'text': '**Пиратский Steam прокачали до неузнаваемости **— Hydra получила САМУЮ крупную обнову за всё время. Теперь это реально мощный конкурент оригиналу.\n\nЧто завезли:\n\n— Новый интерфейс с плавными анимациями и редизайном библиотеки;\n— Добавляй любые .exe: запускай хоть Minecraft, хоть Doom прямо из Hydra;\n— Редактируй игровое время и статистику под себя;\n— Кастомайз обложки, иконки и оформление профиля;\n— Появились лайки, дизы и отзывы;\n— Интеграция с Decky и поддержка Steam Deck;\n— Плюс ускорение загрузок, фильтры, All-Debrid и улучшенная стабильность.\n\nТеперь это тот же Steam, только без цензуры, ограничений и ценников. Работает на Windows и Linux, интерфейс на русском.\n\nГеймеры, вы знаете, что делать — [здесь.](http://hydralauncher.gg/)\n\n@exploitex',
#    'views': 133505,
#    'forwards': 4374,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28660,
#    'date': '2025-10-15T09:39:01+00:00',
#    'text': '**IT-сектор России на грани КАТАСТРОФЫ **— многие компании [закроются](https://www.forbes.ru/tekhnologii/547828-ajti-ot-nalogov-it-otrasl-grozit-bankrotstvom-razrabotcikov-i-ottokom-kadrov) из-за резкого роста налогов или будут поглощены крупными игроками, сообщает Forbes.\n\nЗагибайте пальцы: с 2026 года правительство планирует отменить льготы по НДС для отечественного ПО, в два раза повысить страховые взносы для сотрудников и снизить порог выручки для применения упрощённой системы налогообложения с 60 млн до 10 млн рублей. \n\nСамое страшное**: **всё это вместе может увеличить налоговую нагрузку **с 5% до 30% (!) от выручки.** Для малого бизнеса — фактический приговор. Многие окажутся на грани банкротства или будут поглощены крупными игроками. \n\nАналитики прогнозируют сокращение числа вакансий и отток специалистов за границу.\n\nНе надо, дядя.\n\n@exploitex',
#    'views': 144439,
#    'forwards': 2530,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28659,
#    'date': '2025-10-15T08:27:15+00:00',
#    'text': '**⚡️ Макан НЕ ЯВИЛСЯ в военкомат** — в Москве сегодня ожидалось [прибытие](https://t.me/rian_ru/322122) рэпера в сборный пункт.\n\nРИА Новости сообщают, что артист не явился в назначенное время. Ранее рэпер призывал не доверять «желтой прессе» и заявил, что собирается идти служить.\n\nЧто происходит, брат?\n\n@exploitex',
#    'views': 168519,
#    'forwards': 3308,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28658,
#    'date': '2025-10-15T08:05:34+00:00',
#    'text': '**В YouTube появилось ЖИДКОЕ СТЕКЛО **— Google [полностью](https://support.google.com/youtube/thread/380540176) обновили дизайн в веб-версии и приложениях. \n\nТеперь сервис выглядит «модно»: интерфейс плеера полупрозрачный, а кнопки приобрели более округлую форму.\n\nОт этого тренда нигде не скрыться. \n\n@exploitex',
#    'views': 163006,
#    'forwards': 1162,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28657,
#    'date': '2025-10-15T07:35:10+00:00',
#    'text': '',
#    'views': 154105,
#    'forwards': 546,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28656,
#    'date': '2025-10-15T07:35:10+00:00',
#    'text': '',
#    'views': 156930,
#    'forwards': 560,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28655,
#    'date': '2025-10-15T07:35:09+00:00',
#    'text': '',
#    'views': 155721,
#    'forwards': 515,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28654,
#    'date': '2025-10-15T07:35:09+00:00',
#    'text': 'Возле Москва-Сити MR [строит](https://jois.moscow/?utm_source=telegram&utm_medium=chn:1200&utm_campaign=pro:jois_adf:post_set:&utm_content=ads:_cre:_plc:channel%7Cexploitex) новый проект — **премиальный жилой комплекс JOIS**. В 10 минутах пешком находятся станции метро «Полежаевская», «Хорошёвская», а в 4 минутах — МЦК «Хорошёво».\n\nГлавная фишка [проекта](https://jois.moscow/?utm_source=telegram&utm_medium=chn:1200&utm_campaign=pro:jois_adf:post_set:&utm_content=ads:_cre:_plc:channel%7Cexploitex) — квартиры с террасами **до 140 кв. м**. Здесь можно оборудовать фитнес-зону или лаундж с панорамными видами на столицу. На верхних этажах находятся двухуровневые пентхаусы с потолками до 6 метров.\n\nКлубная инфраструктура включает коворкинг с библиотекой, гостиную, игровые для детей и подростков, спортивную студию. На территории — 2,3 га ландшафтного парка, детские и спортплощадки, велодорожки и скульптуры от Cosmoscow. Проектная декларация на [наш.дом.рф](https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/%D0%BA%D0%B0%D1%82%D0%B0%D0%BB%D0%BE%D0%B3-%D0%BD%D0%BE%D0%B2%D0%BE%D1%81%D1%82%D1%80%D0%BE%D0%B5%D0%BA/%D0%BE%D0%B1%D1%8A%D0%B5%D0%BA%D1%82/56687)',
#    'views': 147541,
#    'forwards': 490,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28653,
#    'date': '2025-10-15T05:55:07+00:00',
#    'text': '',
#    'views': 171198,
#    'forwards': 2786,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28652,
#    'date': '2025-10-15T05:55:07+00:00',
#    'text': '',
#    'views': 176873,
#    'forwards': 2777,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28651,
#    'date': '2025-10-15T05:55:06+00:00',
#    'text': '',
#    'views': 173635,
#    'forwards': 2832,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28650,
#    'date': '2025-10-15T05:55:06+00:00',
#    'text': '',
#    'views': 172555,
#    'forwards': 2767,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28649,
#    'date': '2025-10-15T05:55:05+00:00',
#    'text': '',
#    'views': 167536,
#    'forwards': 2811,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28648,
#    'date': '2025-10-15T05:55:05+00:00',
#    'text': '',
#    'views': 170335,
#    'forwards': 2759,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28647,
#    'date': '2025-10-15T05:55:05+00:00',
#    'text': '**Новенькие китайские Geely теряют управление прямо во время ДВИЖЕНИЯ **— машины массово [выходят](https://t.me/bazabazon/41565) из строя из-за внезапных поломок моторов.\n\nПричина: заводской брак. Жительница Ростова-на-Дону Виктория Т. рассказала, что её Geely Cityray сломалась через пять дней после покупки по параллельному импорту: двигатель задымился, цилиндры залило маслом. Замена — 265 тысяч рублей, гарантия не помогла.\n\nПо информации «Базы», аналогичные проблемы возникли у ДЕСЯТКОВ владельцев Geely Monjaro и Boyue Pro 2025 года. Компания пока не дала официальных комментариев.\n\nКитайское качество. \n\nUPD. Компания Geely Motors знает о редких обращениях владельцев по работе двигателя и проводит сервисные кампании по обновлению его программного обеспечения.\n\n@exploitex',
#    'views': 165879,
#    'forwards': 2830,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28646,
#    'date': '2025-10-14T21:28:31+00:00',
#    'text': '**Динозавров ВОСКРЕСИЛИ в Китае, ну почти **— Unitree использует своих робособак на максимум. \n\nРоботов наряжают в динозавровый косплей и отправляют развлекать посетителей парка. \n\nЖдём полноценный парк Юрского периода.\n\n@exploitex',
#    'views': 204172,
#    'forwards': 2440,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28645,
#    'date': '2025-10-14T17:30:02+00:00',
#    'text': '⚡️ **В ChatGPT добавят ЭРОТИКУ** —  бот сможет заниматься секстингом с пользователями, сообщил сам Альтман.\n\nДля контента 18+ придётся подтвердить свой возраст.\n\nЧто происходит?\n\n@exploitex',
#    'views': 209555,
#    'forwards': 2998,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28644,
#    'date': '2025-10-14T16:45:29+00:00',
#    'text': 'Доллар: падает на пару рублей.\n\nВся телега:\n\n@exploitex',
#    'views': 203097,
#    'forwards': 1732,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28643,
#    'date': '2025-10-14T14:35:49+00:00',
#    'text': '',
#    'views': 208681,
#    'forwards': 3485,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28642,
#    'date': '2025-10-14T14:35:49+00:00',
#    'text': '',
#    'views': 210087,
#    'forwards': 3450,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28641,
#    'date': '2025-10-14T14:35:48+00:00',
#    'text': '',
#    'views': 209763,
#    'forwards': 3628,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28640,
#    'date': '2025-10-14T14:35:48+00:00',
#    'text': 'У военных США теперь волхак — компания **Anduril** [выпустила](https://www.theverge.com/news/798821/anduril-eagleeye-palmer-luckey-mark-zuckerberg-meta-military-mr) шлем **EagleEye**, **который позволяет видеть сквозь стены.**\n\nИИ в реальном времени считывает видео с дронов и камер напарников, подсвечивая их и врагов через любые препятствия. Для разработки юзали лучшие идеи VR-гейминга от Microsoft и Oculus.\n\nСкоро все КТ будут с читами.\n\n@exploitex',
#    'views': 200381,
#    'forwards': 3570,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28639,
#    'date': '2025-10-14T13:13:08+00:00',
#    'text': 'Тем временем АвтоВАЗ подготовил авто, за которое не придётся платить утильсбор — ведь у него нет двигателя.\n\n@exploitex',
#    'views': 204186,
#    'forwards': 4696,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28638,
#    'date': '2025-10-14T12:54:12+00:00',
#    'text': '**⚡️ Решение по утильсбору отложили на МЕСЯЦ **— теперь ожидается, что новые правила вступят в силу **1 декабря**. \n\nОтмените пожалуйста.\n\n@exploitex',
#    'views': 182651,
#    'forwards': 1425,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28637,
#    'date': '2025-10-14T11:38:10+00:00',
#    'text': '',
#    'views': 198164,
#    'forwards': 2623,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28636,
#    'date': '2025-10-14T11:38:09+00:00',
#    'text': '',
#    'views': 201689,
#    'forwards': 2549,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28635,
#    'date': '2025-10-14T11:38:09+00:00',
#    'text': '',
#    'views': 193125,
#    'forwards': 2574,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28634,
#    'date': '2025-10-14T11:38:08+00:00',
#    'text': '**Зумеры устроили революцию в Мадагаскаре **— президент страны Андри Радзуэлина в панике [сбежал](https://www.gazeta.ru/politics/2025/10/14/21856820.shtml) на самолёте.\n\nВ этот раз виноват не блок соцсетей: 25 сентября участники движения «Поколение Z Мадагаскара» вышли на улицы с флагами из аниме **One Piece **— они устали от жёстких перебоев со светом и водой. Настроены были радикально: требовали решения проблем бедности и коррупции.\n\nСкоро к митингам присоединились местные профсоюзы и общественные организации. Власти пытались ввести комендантский час, но это не помогло. В итоге армия тоже восстала против президента и тому пришлось ливать из катки.\n\nНовым правителем Мадагаскара выберут короля Джулиана.\n\n@exploitex',
#    'views': 190261,
#    'forwards': 2490,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28633,
#    'date': '2025-10-14T10:50:07+00:00',
#    'text': 'В России [появился](https://www.forbes.ru/tekhnologii/547761-andeks-zapustil-v-poiske-instrument-dla-sravnenia-cen-na-tovary-s-rynocnymi) **первый полноценный ценовой бенчмаркинг внутри поисковика** — Яндекс внедрил технологию «ОК-цена» прямо в Поиск.\n\nВ выдаче теперь есть цветные метки около товаров: зелёная «Ниже рынка», белая «ОК-цена» и оранжевая «Выше рынка». \n\nПод капотом технология, которая анализирует 4 млрд предложений со всего рунета. Она учитывает характеристики, регион и динамику цен за последние 48 часов.\n\n@exploitex',
#    'views': 181978,
#    'forwards': 789,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28632,
#    'date': '2025-10-14T10:10:55+00:00',
#    'text': '**Девушка постоянно забывала про таблетки, и парень сделал для неё бота в Telegram **— тулза не даёт пропустить ни один приём.\n\nСервис присылает уведомления, после которых нужно принять таблетку и нажать кнопку «Выпила». При этом он поддерживает и называет «котиком», а создать такую штуку можно всего за пару кликов в ChatGPT.\n\nСамые нужные технологии, когда тебе за 25.\n\n@exploitex',
#    'views': 188476,
#    'forwards': 3071,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28631,
#    'date': '2025-10-14T09:52:10+00:00',
#    'text': 'Зелёная сова достанет вас везде.\n\n@exploitex',
#    'views': 183345,
#    'forwards': 1836,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28630,
#    'date': '2025-10-14T09:20:09+00:00',
#    'text': 'У российских ритейлеров [стартовал предзаказ](https://www.ferra.ru/news/notebooks/v-rossii-startoval-predzakaz-na-huawei-matepad-12x-s-ultrayarkim-ekranom-i-pro-stilusom-13-10-2025.htm) на мастхэв для творческой работы — планшет **MatePad 12 X**.\n\nЕго главный и незаменимый плюс — **ультраяркий 12-дюймовый экран**. Также планшет имеет сразу предустановленное приложение **GoPaint**, компьютерную версию **WPS Office** и продвинутые ИИ-фичи Алисы Про. В общем, полный набор сервисов для продуктивности и решения креативных задач. \n\nПланшет отлично заменит ноутбук. Он лёгкий, прочный и удобный. Первым покупателям обновлённый стилус HUAWEI M-Pencil Pro доступен всего за 1 рубль. \n\nЗаказываем этого красавца — [здесь](https://clck.ru/3Pj2Mf).',
#    'views': 185444,
#    'forwards': 479,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28629,
#    'date': '2025-10-14T08:55:13+00:00',
#    'text': '⚡️ **Новый утильсбор ПЕРЕНОСИТСЯ **— первый вице-премьер РФ Денис Мантуров [попросил](https://ria.ru/20251014/manturov-2048132668.html) проработать возможную отсрочку введения новых правил.\n\nРанее стало известно, что утильсбор в России вырастет в 500 (!) раз с 1 ноября, а для гибридных авто и электрокаров — почти в 1000 раз. Но теперь решение по нему перенесли. \n\nЖдем отсрочку «навсегда».\n\n@exploitex',
#    'views': 203670,
#    'forwards': 3342,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28628,
#    'date': '2025-10-14T07:59:27+00:00',
#    'text': "⚡️ **Лента выкупает всю сеть О'кей **— сумму сделки [оценивают](https://www.interfax.ru/business/1052470) в 40-55 миллиардов рублей.\n\nВ ФАС уже согласовали договор. Компания получит 77 гипермаркетов и 224 супермаркета «ДА!».\n\nВ самом ведомстве говорят, что сделка не ограничит конкуренцию на рынке. \n\n@exploitex",
#    'views': 204107,
#    'forwards': 3422,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28627,
#    'date': '2025-10-14T05:42:53+00:00',
#    'text': '⚡️ **Скамеры начали массово подделывать голоса ДЕТЕЙ **с помощью ИИ, чтобы [выманивать](https://ria.ru/20251014/moshenniki-2048089887.html) деньги у родителей — РИА Новости. \n\nНа уловку попалось множество людей: злоумышленники звонят, представляясь детьми, и под предлогом сбора денег на подарок ко дню рождения просят перевести несколько тысяч рублей или сообщить данные банковской карты.\n\nСамое время придумать кодовую фразу.\n\n@exploitex',
#    'views': 217854,
#    'forwards': 2920,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28626,
#    'date': '2025-10-13T21:00:54+00:00',
#    'text': '**Windows 10 КОНЕЦ** — сегодня Microsoft официально прекращают поддержку системы, которая была с нами **десять лет**.\n\nТри варианта, как пережить утрату:\n\n1.** Бесплатно получаем платные обновления**:\n\nНаш [гайд](https://t.me/exploitex/28291) поможет продлить жизнь ещё на год. А если отсутствие обновлений безопасности вас не пугает — на вечность.\n\n**2. Устанавливаем лучшую сборку Windows 11:**\n\nЛучший способ вкатиться в новую ОС — в этой [сборке](https://t.me/exploitex/28472) вырезали весь мусор и слежку, которые нагружали бы ваш ПК. Выбираем этот вариант, если хотите пользоваться актуальным версиями программ и играть в современные игры.\n\n**3. Вкатываемся в Linux:**\n\nВозможно, самое время избавиться от монополии Windows и переехать на **свободную систему**. Один[ шестичасовой курс](https://youtu.be/sWbUDq4S6Y8?si=xiXzDnWIgeppsfcx) и можете гордо называть себя сисадмином.\n\n@exploitex',
#    'views': 230829,
#    'forwards': 5697,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28625,
#    'date': '2025-10-13T16:40:46+00:00',
#    'text': '**7-Zip УНИЧТОЖИТ ваш комп вирусам**и — в сервисе [нашли](https://www.tomshardware.com/tech-industry/cyber-security/7-zip-flaws-open-door-to-remote-code-execution) критическую уязвимость.\n\nОдин из самых популярных архиваторов **оказался дырявым** — уязвимость нашли ещё летом, но у 7-Zip нет автообновления, поэтому тревогу забили только сейчас.\n\nСрочно обновляемся — [здесь](https://www.7-zip.org/download.html).\n\n@exploitex',
#    'views': 221868,
#    'forwards': 2398,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28624,
#    'date': '2025-10-13T16:02:13+00:00',
#    'text': 'В Твиттере [раскрыли](https://x.com/immasiddx/status/1977384634250875262) единственный правильный способ носить AirPods.\n\nApple это скрывают.\n\n@exploitex',
#    'views': 213279,
#    'forwards': 1837,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28623,
#    'date': '2025-10-13T15:22:35+00:00',
#    'text': 'Избегаем трудностей с оформлением документов и расчётов **из-за новой ставки НДС** — с помощью Онлайн-Бухгалтерии от Точка Банка.\n\nСервис поможет бизнесу перестроить процессы и избежать ошибок, когда налоговая реформа вступит в силу. В новых тарифах:\n\n— Автоматический расчёт НДС и налогов по УСН;\n— Формирование и отправка деклараций прямо из сервиса с помощью электронной подписи или смс-кода;\n— Работа в ЭДО: создавайте и отправляйте первичку, УПД и счета-фактуры;\n— Поддержка по любым вопросам от опытных бухгалтеров;\n— Учёт маркетплейсов, включая комиссии площадок;\n— Страховка от ошибок до 100 млн рублей.\n\n[Подключаемся](https://tochka.com/rko/accounting-20/usn-nds/?utm_source=telegram&utm_medium=cpv&utm_campaign=ob_nds&utm_term=exploitex&utm_content=131025&erid=2VtzquX6t7f) прямо сейчас и закрываем 2025-й со спокойной душой. Тем более до конца октября **действует скидка 20%.**',
#    'views': 196474,
#    'forwards': 455,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28622,
#    'date': '2025-10-13T15:13:48+00:00',
#    'text': '⚡️** Аниме** по **Duolingo** **ВЫШЛО **— первый эпизод мульта уже можно глянуть на YouTube.\n\nБудет ещё 4 серии — все они **на японском языке**, чтобы смотивировать вас учить его.\n\nКонишуа, зелёная сова — [здесь](https://www.youtube.com/watch?v=9MWtNC_rZmI).\n\n@exploitex',
#    'views': 186795,
#    'forwards': 1565,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28621,
#    'date': '2025-10-13T14:35:56+00:00',
#    'text': '**Чтобы завести кошку или собаку в России, теперь нужен будет ДОПУСК **— Минприроды [готовит](https://aif.ru/society/law/lohmatyy-vopros-dopusk-k-soderzhaniyu-koshek-i-sobak-mozhet-poyavitsya-v-rossii) законопроект с обязательной регистрацией всех питомцев в единой базе.\n\nПлан такой: перед покупкой щенка или котёнка предстоит подтвердить, что его будущее жильё соответствует норме — максимум одна взрослая кошка или собака на 18 кв. м. \n\nВсё ради борьбы с «кошкиными домами» и бродячими животными. Но в скором времени завести питомца может быть сложнее.\n\n@exploitex',
#    'views': 195764,
#    'forwards': 3353,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28620,
#    'date': '2025-10-13T14:03:10+00:00',
#    'text': 'В России появится **Институт социальной архитектуры** — об этом [заявил](https://dzen.ru/shorts/68e63c0e22378333daa9d5e0?share_to=link) глава управления президента России по вопросам мониторинга и анализа социальных процессов Александр Харичев на Международном симпозиуме «Создавая будущее».\n\nУчреждение** **будет анализировать социум, прогнозировать развитие общества, моделировать БУДУЩЕЕ и разрабатывать практические стратегии развития.\n\nОткроют институт на базе платформы «Россия — страна возможностей».\n\n@exploitex',
#    'views': 187128,
#    'forwards': 705,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28619,
#    'date': '2025-10-13T13:41:35+00:00',
#    'text': 'Бизнес-идея: пермяк [отсудил](https://perm.rbc.ru/perm/freenews/68e7fca89a79470557d9319b) у АвтоВАЗа** 4 миллиона рублей **из-за дефектной **Lada Granta за 860 тысяч рублей**.\n\nАвтомобиль оказался с подвохом: стеклоподъёмники не работали, подшипники гудели и **это** только часть проблем. Суд признал все косяки производственными и обязал дилера **вернуть деньги, снять залог и погасить креди**т.\n\nВ итоге мужчина получил х5 от цены автомобиля.\n\n@exploitex',
#    'views': 191859,
#    'forwards': 1865,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28618,
#    'date': '2025-10-13T10:45:02+00:00',
#    'text': '',
#    'views': 203394,
#    'forwards': 2203,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28617,
#    'date': '2025-10-13T10:45:02+00:00',
#    'text': '',
#    'views': 217280,
#    'forwards': 2268,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28616,
#    'date': '2025-10-13T10:45:02+00:00',
#    'text': '**Китайцы выпустили стиралку специально для носков и трусов **— в Dreame Double Yolk Egg два небольших барабана, которые [вмещают](https://www.ixbt.com/news/2025/10/13/340-dreame-double-yolk-egg.html) всего по 0,5 кг.\n\nГлавная фича стирально-сушильной машины: можно стирать сразу два типа вещей без ожидания завершения одного цикла. Модель оснащена несколькими автоматическими программами.\n\nТакже девайс позволяет избежать перекрёстного бактериального загрязнения, вызванного смешиванием носков с другими вещами.\n\nЦена мечты холостяка — 340 баксов (~27500 рублей).\n\n@exploitex',
#    'views': 198341,
#    'forwards': 2195,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28615,
#    'date': '2025-10-13T09:16:34+00:00',
#    'text': '⚡️ **Hollywood Undead приедут в Россию** — нас [ждут](http://daily.afisha.ru/news/102883-hollywood-undead-vystupyat-v-rossii-v-2026-godu/) концерты в Питере (30 мая) и в Москве (28 мая).\n\nПродажа билетов стартует с** 16 октября**.\n\nЕвривер ай го, битчес олвейс ноу.\n\n@exploitex',
#    'views': 217347,
#    'forwards': 4793,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28614,
#    'date': '2025-10-13T08:46:14+00:00',
#    'text': 'Последний шанс залететь на AI Journey Contest с** призовым фондом в 6,5 миллионов рублей** — международное соревнование по ИИ закончит прием решений уже 30 октября.\n\nОрганизаторы дают выбрать один или несколько треков:\n\n**Agent-as-Judge **— нужно создать универсального «судью» для оценки текстов, сгенерированных ИИ.\n\n**Human-centered AI Assistant** — нужно разработать персонализированного ассистента на основе GigaChat. **Бонус**: Участникам предоставляются токены для API + возможность получить дополнительно 1 млн токенов. \n\n**GigaMemory** — нужно придумать механизм долговременной памяти для LLM.\n\nУспеваем зарегаться — [здесь.](https://dsworks.ru/group/aij2025/?utm_source=telegram&utm_medium=fix&utm_campaign=aij_contest_tg_seeding_october_post&utm_term=exploitex&erid=2Vtzqufwpbw)',
#    'views': 200216,
#    'forwards': 579,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28613,
#    'date': '2025-10-13T07:43:10+00:00',
#    'text': '',
#    'views': 205727,
#    'forwards': 5425,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28612,
#    'date': '2025-10-13T07:43:09+00:00',
#    'text': '',
#    'views': 208947,
#    'forwards': 5394,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28611,
#    'date': '2025-10-13T07:43:09+00:00',
#    'text': '',
#    'views': 200259,
#    'forwards': 5459,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28610,
#    'date': '2025-10-13T07:43:08+00:00',
#    'text': '**Весёлая ферма научит вас кодить** — в [Steam](https://store.steampowered.com/app/2060160/The_Farmer_Was_Replaced/) вышла топовая игра **The Farmer Was Replaced**.\n\nВам предстоит управлять целой фермой дронов, которые управляются с помощью команд на упрощённой версии Python. Русский язык на месте.\n\nЛучше любых курсов — [забираем](https://store.steampowered.com/app/2060160/The_Farmer_Was_Replaced/).\n\n@exploitex',
#    'views': 197376,
#    'forwards': 5448,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28609,
#    'date': '2025-10-13T06:21:52+00:00',
#    'text': '**В Африке диагностируют туберкулез с помощью... КРЫС **— HeroRAT, дрессированные африканские крысы, способны [обнаружить](https://apopo.org/herorats/?v=288404204e3d) болезнь по запаху всего за 3 секунды.\n\nОдна такая крыса проверяет до 100 образцов мокроты за 20 минут, тогда как технику в лаборатории на это понадобилось бы четыре дня. **Точность до 90%**, и при этом грызуны находят случаи, которые микроскописты часто пропускают.\n\nРаботают крысы быстро, безопасно и за вознаграждение — банан.\n\n@exploitex',
#    'views': 223247,
#    'forwards': 3151,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28608,
#    'date': '2025-10-12T22:57:01+00:00',
#    'text': 'Спокойной ночи и приятного аппетита.\n\nГенерации Sora становятся слишком реалистичными.\n\n@exploitex',
#    'views': 240009,
#    'forwards': 4356,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28607,
#    'date': '2025-10-12T19:24:12+00:00',
#    'text': '**Все криптокошельки Trust Wallet ОБНУЛИЛИСЬ** — у компании жёсткий сбой.\n\nНе пугаемся: если нажать «Отправить», монеты будут на месте.\n\nUPD: сбой устранили, баланс вернулся.\n\n@exploitex',
#    'views': 236385,
#    'forwards': 674,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28606,
#    'date': '2025-10-12T16:15:04+00:00',
#    'text': '⚡️ **Банк России ОТМЕНИЛ голосование **по [выбору](https://t.me/centralbank_russia/3012) символов для банкноты в 500 рублей — за «некоторые объекты» крутили голоса.\n\nХорошая новость: банк проведёт повторное голосование, но когда — неизвестно.\n\n@exploitex',
#    'views': 245908,
#    'forwards': 2102,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28605,
#    'date': '2025-10-12T15:34:48+00:00',
#    'text': '',
#    'views': 237246,
#    'forwards': 3868,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28604,
#    'date': '2025-10-12T15:34:48+00:00',
#    'text': '',
#    'views': 240802,
#    'forwards': 4007,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28603,
#    'date': '2025-10-12T15:34:47+00:00',
#    'text': '',
#    'views': 236617,
#    'forwards': 3933,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28602,
#    'date': '2025-10-12T15:34:47+00:00',
#    'text': 'Зовём корешей разбирать «жигуль» — в [Steam](https://store.steampowered.com/app/3501070/Car_Service_Together/) вышла демка угарного коопа про автомехаников.\n\nВместе с 3 друзьями предстоит ~~пить пиво~~ ремонтировать разные корыта, тюнить их и строить свою бизнес-империю. На готовой тачке можно устроить тестовый заезд.\n\nЗалетаем бесплатно — [здесь](https://store.steampowered.com/app/3501070/Car_Service_Together/).\n\n@exploitex',
#    'views': 227571,
#    'forwards': 4113,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28601,
#    'date': '2025-10-12T10:11:39+00:00',
#    'text': '**Зумеры массово ложатся в ДУРКУ, чтобы... отдохнуть **— молодёжь [открыла](https://t.me/bazabazon/41519) новый вид исцеляющего туризма.\n\nОфисная гонка, постоянные дедлайны, шум города и бесконечное достигаторство довели поколение до тревоги и выгорания. \n\nВ частных психдиспансерах зумерки находят тишину, строгий распорядок и возможность восстановить силы без залипаний в смартфон. \n\n@exploitex',
#    'views': 244145,
#    'forwards': 3816,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28600,
#    'date': '2025-10-12T09:01:40+00:00',
#    'text': '**Улететь в Стамбул из Москвы можно за 228 рублей **— цену на ноябрьские рейсы скинули в 50 (!) раз.\n\nКто куда, а мы в отпуск.\n\n@exploitex',
#    'views': 234986,
#    'forwards': 5565,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28599,
#    'date': '2025-10-12T07:12:38+00:00',
#    'text': 'Зависть: в Китае невеста [подарила](http://tomshardware.com/pc-components/gpus/bride-surprises-new-husband-with-an-rtx-5090-on-wedding-day-chinese-number-slang-reveals-surprise-gift) мужу новенькую RTX 5090 в честь свадьбы.\n\nДевушка максимально запарилась и вывалила на возлюбленного математический пример 520 × 10 + 1314 - 514 - 619 + 666 - 957 — на китайском числа звучат похоже на «Я люблю тебя всю жизнь».\n\nНевеста года.\n\n@exploitex',
#    'views': 223118,
#    'forwards': 2501,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28598,
#    'date': '2025-10-12T06:53:45+00:00',
#    'text': '',
#    'views': 207510,
#    'forwards': 2043,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28597,
#    'date': '2025-10-12T06:53:45+00:00',
#    'text': '**Первую в мире мышь... с подогревом и охлаждением выпустили Black Shark **— температура корпуса может [повышаться](https://www.ixbt.com/news/2025/10/12/black-shark-star-flash.html) на 20 °C и снижаться на 10,3 °C.\n\nВнутри система контроля температуры TempX: в режиме нагрева корпус превращается в грелку для ладони, а при охлаждении встроенный вентилятор на 4700 об/мин снижает температуру.\n\nМышь оснащена сенсором PAW3950 с частотой опроса 8000 Гц и долговечными переключателями на 80–100 млн нажатий. Старт продаж запланирован на 14 октября, цена — 62 доллара (~5 тыс. рублей).\n\nВ случае проигранной катки можно охладить пятую точку.\n\n@exploitex',
#    'views': 216418,
#    'forwards': 1959,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28596,
#    'date': '2025-10-11T22:12:02+00:00',
#    'text': '',
#    'views': 250676,
#    'forwards': 3847,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28595,
#    'date': '2025-10-11T22:12:02+00:00',
#    'text': 'Китай [показал](https://www.nytimes.com/2025/10/10/business/china-solar-tibetan-plateau.html) миру свою ферму солнечных панелей и у журналистов NYT натурально отвалилась челюсть — в горах Тибета спрятано поле из кремниевых плит **размером с половину Москвы**.\n\nВ Талатанском солнечном парке раскинулись поля на **420 квадратных километров панелей** на высоте почти трёх километров над уровнем моря. География решает: в этом месте разрежённый воздух, благодаря чему солнце светит ярче, а холод дополнительно бустит выработку электричества.\n\nИ это ещё не всё: к 2028 **площадь панелей УДВОЯТ**, а к 2030 **выработку энергии увеличат в ПЯТЬ раз**. Для понимания: уже сейчас с полей собирают почти 17 ГВт мощности — этого хватит, чтобы питать всю Москву в пиковую нагрузку.\n\nНочью горы не стоят без дела — по всему хребту крутятся ветряки и работают гидроэлектростанции. Вся эта мощная махина используется для китайских айти-гигантов: подготовки нового DeepSeek или программирования роботов.\n\nШёл 2025 год — Китай самая «зелёная» страна.\n\n@exploitex',
#    'views': 250571,
#    'forwards': 3913,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28594,
#    'date': '2025-10-11T14:01:58+00:00',
#    'text': 'Секрет продуктивности оказался прост.\n\n@exploitex',
#    'views': 233711,
#    'forwards': 2172,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28593,
#    'date': '2025-10-11T10:56:04+00:00',
#    'text': '**Пользователи нашли способ спасти смартфоны Samsung** — он простой и воскресит телефон после «окирпичивания».\n\nПосле обновления вытаскиваем SIM-карту с телефона и перезагружаем его. Да, настолько просто.\n\nЕсли не помогает, остаётся только полностью сбросить телефон — вы потеряете все фотки, настройки и приложения вне облака. \n\nДля этого выключаем телефон, подключаем по проводу к ПК и включаем с зажатой кнопкой повышения (или уменьшения) громкости. Дальше выбираем **Wipe data/factory reset** и подтверждаем удаление.\n\n@exploitex',
#    'views': 230191,
#    'forwards': 1949,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28592,
#    'date': '2025-10-11T09:18:42+00:00',
#    'text': '',
#    'views': 230904,
#    'forwards': 5058,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28591,
#    'date': '2025-10-11T09:18:42+00:00',
#    'text': '⚡️ **Смартфоны Samsung массово превращаютcя в КИРПИЧ после установки обновы One UI 8 **— ни в коем [случае](https://t.me/bazabazon/41493) НЕ ОБНОВЛЯЙТЕСЬ. \n\nПервые случаи зафиксированы в Южной Корее, а теперь о фатальных проблемах сообщают и российские юзеры. \n\nПо данным «Базы», телефон уходит в бесконечную анимацию при старте, а после перезагрузки показывает лишь приветственный экран с надписью «Добро пожаловать». Единственное, что остаётся работоспособным — **возможность принимать звонки.**\n\nПредупредите знакомых самсунгеров.\n\n@exploitex',
#    'views': 235325,
#    'forwards': 5082,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28590,
#    'date': '2025-10-11T07:45:58+00:00',
#    'text': 'Единственным стабильным активом оказались... **скины в CS2** — они не только не упали из-за действий Трампа, но и немного выросли в цене.\n\nМам, я инвестор.\n\n@exploitex',
#    'views': 223636,
#    'forwards': 2364,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28589,
#    'date': '2025-10-11T06:25:12+00:00',
#    'text': '**Превращаем любое фото или видео в текст** — нашли бесплатную тулзу для Windows, которая быстро вытащит текст из всего, что вы видите на экране.\n\n— Распознаёт почти идеально, даже если картинка шакальная;\n— Работает локально через OCR API;\n— Просто выделите область захвата или весь экран целиком;\n— Можно превращать фотки в текст целыми папками;\n— Запускается элементарно.\n\nСохраняем годноту — [здесь](https://github.com/TheJoeFin/Text-Grab).\n\n@exploitex',
#    'views': 218852,
#    'forwards': 3486,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28588,
#    'date': '2025-10-10T22:08:03+00:00',
#    'text': 'Трампкоин резко потерял половину цены, но затем кто-то внезапно начал **откупать монету по дешёвке**.\n\nДональд, ты палишься.\n\n@exploitex',
#    'views': 230844,
#    'forwards': 1667,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28586,
#    'date': '2025-10-10T21:47:34+00:00',
#    'text': 'Агент Краснов докладывает.\n\n@exploitex',
#    'views': 221614,
#    'forwards': 3065,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28585,
#    'date': '2025-10-10T21:36:24+00:00',
#    'text': 'Полная картина ада на крипторынке:** почти все альткоины в минусе на 50-60%**.\n\nТрамп, что ты наделал.\n\n@exploitex',
#    'views': 212714,
#    'forwards': 2430,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28584,
#    'date': '2025-10-10T21:31:02+00:00',
#    'text': '⚡️ **BTC рухнул до 105 000 долларов** — это самая низкая цена за год.\n\nТем временем крипторынок потерял** 318 МИЛЛИАРДОВ долларов**.\n\nТрамп мстит за Нобелевскую премию.\n\n@exploitex',
#    'views': 206533,
#    'forwards': 2263,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28583,
#    'date': '2025-10-10T21:23:18+00:00',
#    'text': '⚡️ TON УМЕР — монета резко потеряла в цене 80% стоимости\n\nЧто происходит?\n\n@exploitex',
#    'views': 202492,
#    'forwards': 3055,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28582,
#    'date': '2025-10-10T21:14:32+00:00',
#    'text': '**⚡️ Вся крипта летит вниз **— торпеду на дно запустил Трамп: он заявил, что США введут 100% пошлины поверх текущих для Китая с 1 ноября.\n\nБиткоин за несколько минут потерял сразу 5% (!) стоимости и продолжает падать. \n\nУ криптанов чёрная суббота.\n\n@exploitex',
#    'views': 202414,
#    'forwards': 2902,
#    'media': True,
#    'media_type': 'MessageMediaPhoto'},
#   {'id': 28581,
#    'date': '2025-10-10T16:51:06+00:00',
#    'text': '',
#    'views': 223856,
#    'forwards': 1478,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28580,
#    'date': '2025-10-10T16:51:06+00:00',
#    'text': '',
#    'views': 238328,
#    'forwards': 1577,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28579,
#    'date': '2025-10-10T16:51:05+00:00',
#    'text': '',
#    'views': 225091,
#    'forwards': 1714,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28578,
#    'date': '2025-10-10T16:51:05+00:00',
#    'text': '',
#    'views': 213830,
#    'forwards': 1619,
#    'media': True,
#    'media_type': 'MessageMediaDocument'},
#   {'id': 28577,
#    'date': '2025-10-10T16:51:04+00:00',
#    'text': '⚡️ **В Телеграм появилось ЖИДКОЕ СТЕКЛО** — обновление в честь дня рождения Паши Дурова [принесло](https://telegram.org/blog/comments-in-video-chats-threads-for-bots/ru) новые фичи. Как всегда — коротко о главном:\n\n— В групповых звонках теперь можно **оставлять комментарии и реакции** — больше не нужно создавать отдельный пост для комментов в трансляции;\n\n— **Дизайн Liquid Glass для iOS 26**: работает в нижней панели навигации, на клавиатуре, в панели стикеров и других блоках;\n\n— Можно оставлять **заметки о контактах** — Getcontact умер;\n\n— ИИ-боты теперь стримят ответы в реальном времени (как у ChatGPT);\n\n— Можно предложить юзеру дату рождения;\n\n— Новые цвета профилей и улучшенный интерфейс подарков;\n\n— Подписи к подаркам теперь можно удалить — больше никакой скрытой рекламы в подписях.\n\nОбновляемся!\n\n@exploitex',
#    'views': 209352,
#    'forwards': 1519,
#    'media': True,
#    'media_type': 'MessageMediaDocument'}]}
